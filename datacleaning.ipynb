# %% [markdown]
# Installation

# %%
# %pip install pandas numpy scikit-learn xgboost matplotlib seaborn

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ramak\OneDrive\Desktop\Employee_Performance_Retention (1).csv")

print("Dataset loaded successfully!")
print(df.head())
# Out:
# Dataset loaded successfully!
#   Employee_ID  Age  Department  Years_of_Experience  Monthly_Working_Hours  \
# 0       E1000   59       Sales                   27                    135
# 1       E1001   49        Tech                   13                    132
# 2       E1002   35  Operations                   16                    197
# 3       E1003   28          HR                   23                    204
# 4       E1004   41  Operations                   33                    192
#
#    Training_Hours_per_Year  Performance_Rating Job_Satisfaction_Level  \
# 0                       30                   3                 Medium
# 1                       36                   5                 Medium
# 2                       11                   5                    Low
# 3                       36                   3                   High
# 4                       36                   2                 Medium
#
#   Promotion_in_Last_2_Years Attrition
# ...

# %%
print(df.isnull().sum())
# Out:
# Employee_ID                  0
# Age                          0
# Department                   0
# Years_of_Experience          0
# Monthly_Working_Hours        0
# Training_Hours_per_Year      0
# Performance_Rating           0
# Job_Satisfaction_Level       0
# Promotion_in_Last_2_Years    0
# Attrition                    0
# dtype: int64

# %% [markdown]
# there r no missing values in any column

# %%
print("Initial Data Shape:", df.shape)

#duplicates
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
df.drop_duplicates(inplace=True)
print("Shape after removing duplicates:", df.shape)


numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print("\nNumeric columns", numeric_cols)
print("Categorical columns", categorical_cols)


numeric_df = df[numeric_cols]
# Out:
# Initial Data Shape: (9000, 10)
# Number of duplicate rows: 0
# Shape after removing duplicates: (9000, 10)
#
# Numeric columns ['Age', 'Years_of_Experience', 'Monthly_Working_Hours', 'Training_Hours_per_Year', 'Performance_Rating']
# Categorical columns ['Employee_ID', 'Department', 'Job_Satisfaction_Level', 'Promotion_in_Last_2_Years', 'Attrition']

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col] = df[col].str.strip()        
    df[col] = df[col].str.replace('\t','')  
    df[col] = df[col].str.replace('\n','')  
    df[col] = df[col].str.title()

# %%
df['Attrition'].isna().any().any()
# Out:
# np.False_

# %% [markdown]
# There are no missing values , and duplicates .. I assume the given dataset is already cleaned , and by the above code it cleaned string formated data too

# %%
df.to_csv(r"C:\Users\ramak\OneDrive\Desktop\CleanedData.csv", index=False)
